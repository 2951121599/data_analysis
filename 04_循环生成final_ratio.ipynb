# %%
import numpy as np
import pandas as pd

# %%
for i in range(len(pd.read_csv('final_is_area.csv').values)):  # 循环几个内标
    print(i)
    input_data1 = pd.read_csv('final_area.csv').values  # 读文件 不包含header
    input_data2 = pd.read_csv('final_is_area.csv').values  # 读文件 不包含header
    col = pd.read_csv('final_area.csv',header=None).values[1:,0:2]  # 前两列数据(去除第一行)
    row = pd.read_csv('final_area.csv',header=None).values[0,:]  # 第一行行名
    feature = input_data2[i,0:1]  # 获取IS内标名称 组成生成的文件名
    feature = feature[0]
    print("feature----------", feature)
    input_data1 = input_data1[0:,2:]  # 纯数据
    input_data2 = input_data2[i,2:]  # 纯数据(一行IS内标值)
    res = np.divide(input_data1,input_data2)  # 做矩阵除法
    res = np.column_stack((col,res))  # 合并列
    res = np.row_stack((row,res))  # 合并行
    print("res----------", res)
    filename = 'final_is_ratio_' + feature +  '.csv'  # 组成生成的文件名
    np.savetxt(filename, res, fmt='%s', delimiter=',')  # numpy.array写文件
# Out:
# 0
# feature---------- Luopaikayin_1
# res---------- [['first' nan 'yx0101' ... 'yx01Ipooled_1' 'yx01Ipooled_2'
#   'yx01Ipooled_3']
#  ['X10.06_547.3433-1' 'Area' 0.052417228301755096 ... 0.08656754155133337
#   0.10937477432331533 0.08419425117717338]
#  ['X10.06_547.3433-2' 'Area' 0.09052568785756572 ... 0.1302265663853161
#   0.065480305921819 0.10815720633135771]
#  ...
#  ['X9.74_333.1467-1' 'Area' 0.006816530814312711 ...
#   0.00023542621199224904 0.0005510435917869072 0.0025759598941129617]
#  ['X9.74_333.1467-2' 'Area' 0.005832538383783547 ... nan
#   0.0014857767956328461 0.00327281529895909]
#  ['X9.74_333.1467-3' 'Area' 0.00565771411287508 ... 0.001577285967622627
#   0.002183137375324425 0.004712129375844324]]
# 1
# feature---------- difukete
# res---------- [['first' nan 'yx0101' ... 'yx01Ipooled_1' 'yx01Ipooled_2'
#   'yx01Ipooled_3']
#  ['X10.06_547.3433-1' 'Area' 2.1695289302624188 ... 3.169108178746733
#   4.430899169390845 3.2156661576636765]
#  ['X10.06_547.3433-2' 'Area' 3.7468234224112567 ... 4.767399757761203
#   2.652683261889922 4.130893300248139]
#  ...
#  ['X9.74_333.1467-1' 'Area' 0.28213359013455314 ... 0.008618601389685726
#   0.022323416055051705 0.09838471082267608]
#  ['X9.74_333.1467-2' 'Area' 0.24140652168097798 ... nan
#   0.06019054402991719 0.125]
#  ['X9.74_333.1467-3' 'Area' 0.23417061231040848 ... 0.057742079428826414
#   0.08844143124260656 0.1799723229623974]]
# 2
# feature---------- kapeitabin
# res---------- [['first' nan 'yx0101' ... 'yx01Ipooled_1' 'yx01Ipooled_2'
#   'yx01Ipooled_3']
#  ['X10.06_547.3433-1' 'Area' 0.2811749206954532 ... 0.5295891018020206
#   0.6450002592266159 0.4663196300582835]
#  ['X10.06_547.3433-2' 'Area' 0.48559517412331643 ... 0.7966793221436759
#   0.38614767029337044 0.5990412378446363]
#  ...
#  ['X9.74_333.1467-1' 'Area' 0.03656502972837109 ... 0.0014402529390960496
#   0.003249590792270603 0.01426725278831632]
#  ['X9.74_333.1467-2' 'Area' 0.03128672710568739 ... nan
#   0.008761859617677774 0.018126867311262083]
#  ['X9.74_333.1467-3' 'Area' 0.030348940005893672 ... 0.00964926858160652
#   0.012874304717183762 0.02609867534431187]]
# 3
# feature---------- lifuping
# res---------- [['first' nan 'yx0101' ... 'yx01Ipooled_1' 'yx01Ipooled_2'
#   'yx01Ipooled_3']
#  ['X10.06_547.3433-1' 'Area' 8.449161370976144 ... 7.488822607857315
#   9.6318088812697 11.264103635603844]
#  ['X10.06_547.3433-2' 'Area' 14.591884571309512 ... 11.265696553386357
#   5.766355140186916 14.470037609694943]
#  ...
#  ['X9.74_333.1467-1' 'Area' 1.0987602875299511 ... 0.020366353338153773
#   0.04852624011502516 0.34463017133305474]
#  ['X9.74_333.1467-2' 'Area' 0.9401500156266278 ... nan 0.1308411214953271
#   0.43786042624320937]
#  ['X9.74_333.1467-3' 'Area' 0.9119699968746744 ... 0.13644854181730537
#   0.19225239174915668 0.6304220643543669]]
# 4
# feature---------- lvbingqing
# res---------- [['first' nan 'yx0101' ... 'yx01Ipooled_1' 'yx01Ipooled_2'
#   'yx01Ipooled_3']
#  ['X10.06_547.3433-1' 'Area' 14.56469426236868 ... 27.07723311546841
#   31.230410615026 26.94152923538231]
#  ['X10.06_547.3433-2' 'Area' 25.153542246565504 ... 40.73322440087146
#   18.696969696969695 34.60949525237381]
#  ...
#  ['X9.74_333.1467-1' 'Area' 1.894046870791057 ... 0.07363834422657953
#   0.15734265734265734 0.824287856071964]
#  ['X9.74_333.1467-2' 'Area' 1.6206339229595044 ... nan
#   0.42424242424242425 1.0472763618190906]
#  ['X9.74_333.1467-3' 'Area' 1.5720571069408278 ... 0.49335511982570807
#   0.623363815671508 1.5078460769615192]]
# 5
# feature---------- pifeinitong
# res---------- [['first' nan 'yx0101' ... 'yx01Ipooled_1' 'yx01Ipooled_2'
#   'yx01Ipooled_3']
#  ['X10.06_547.3433-1' 'Area' 0.5664918138131426 ... 0.7055265570494753
#   0.9726991715090709 0.9193790993461511]
#  ['X10.06_547.3433-2' 'Area' 0.9783436242735807 ... 1.0613481608891993
#   0.5823339039039878 1.1810482729452534]
#  ...
#  ['X9.74_333.1467-1' 'Area' 0.07366869691551185 ... 0.0019187266013277816
#   0.0049005782961624705 0.028128805165304055]
#  ['X9.74_333.1467-2' 'Area' 0.06303433728207421 ... nan
#   0.013213411109652882 0.03573828307530689]
#  ['X9.74_333.1467-3' 'Area' 0.061144948591864104 ... 0.012854900558304027
#   0.019415225580181 0.051455214590005696]]
